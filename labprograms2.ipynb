# %%
'''
datasets in sklearn lib
load_iris
load_boston
load_digits
load_diabates
load_breast_cancer
load_wine
load_linnuerud
'''

# %%
# p(a|b) = p(a intersection b)/p(b)
pab = 0.03
pa = 0.2
print("The student is absent given by Friday : ",pab/pa)
# Out:
# The student is absent given by Friday :  0.15

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import pandas

# Loading data 
irisdata = load_iris()
X=irisdata.data
Y=irisdata.target

# Training data
xtrain,xtest,ytrain,ytest = train_test_split(X,Y)

# Implementing KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(xtrain,ytrain)
print(model.predict(xtest))
# Out:
# [1 0 0 0 2 1 2 2 2 1 0 2 1 0 1 2 0 1 0 0 0 2 0 2 2 2 2 2 2 1 2 2 2 1 1 1 1
#  1]

# %%
#implementing kmeans
from sklearn.cluster import KMeans
data = pandas.read_csv("Kmeans.csv")
features= ['VAR1',"VAR2"]
X = data[features]
Y = data['CLASS']
kmean = KMeans(n_clusters = 3)
kmean.fit(X,Y)
print(kmean.predict([[eval(input("VAR1")),eval(input("VAR2:"))]]))

# %% [raw]
# '''
# input attributes are (from left to right) income, recreation, job, status, age-group, home-owner.  Find the
# unconditional probability of `golf' and the conditional probability of `single' given `medRisk' in the
# dataset?
# '''
# print("Uncoditional Probability of Golf : ",4/10)
#
# single = 5/10
# medrisk = 3/10
# print("Conditional Probability of Single given Medrisk",single*medrisk/medrisk)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

data = load_iris()
X = data.data
Y = data.target
xtrain,xtest,ytrain,ytest = train_test_split(X,Y)
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypredict = lr.predict(xtest)
print(ypredict)
# Out:
# [ 1.83857529  0.01792744 -0.01821281  0.83804457  0.10161152  1.42132698
#   2.17650246  1.16126982  1.81808051  0.16622771  0.99457778  1.65709706
#   2.02097285  0.93848615  0.90696365  1.31358237  1.70723788  1.19995003
#   1.75587057 -0.09864499  1.87905728  1.04719952  0.88841597  1.12244431
#  -0.09976966  1.33974793  0.00803803  1.45390047  0.01120465  0.92294918
#  -0.02400467  1.28718723  1.77147918  1.57469356 -0.0946539   1.57845506
#   2.28787386  1.25190627]

# %%
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

data =pd.read_csv('text.csv')
X = data['message']
Y = data['label']
xtrain,xtest,ytrain,ytest = train_test_split(X,Y)
# Tokenising
count = CountVectorizer()
xtrain_token = count.fit_transform(xtrain)
xtest_token =  count.transform(xtest)
# Model 
NB = MultinomialNB()
NB.fit(xtrain_token,ytrain)
print(NB.predict(xtest_token))
# Out:
# [1 1 1 0 1]

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
sourcedata = load_iris()
X = sourcedata.data
Y = sourcedata.target

xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.2)

svm_model = SVC()
svm_model.fit(xtrain,ytrain)
y_predict=svm_model.predict(xtest)

acc = accuracy_score(y_predict,ytest)
print(acc)

import matplotlib.pyplot as plt
plt.scatter(xtest[:,0],y_predict)
plt.title('SVM Implementation')
plt.xlabel('Feature Attribute')
plt.ylabel('Predicted Output')
plt.show()
# Out:
# 1.0
# [5.8 5.6 6.7 5.7 5.  5.1 6.9 6.9 5.7 5.8 7.7 4.9 5.2 5.6 4.9 6.5 6.  4.4
#  5.8 5.  4.4 6.7 6.8 5.4 6.2 6.7 6.8 6.6 5.4 7.2]
# [2 1 2 0 0 0 2 2 1 0 2 1 0 1 0 2 1 0 2 0 0 2 1 0 1 2 2 1 0 2]

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import  accuracy_score
from sklearn.datasets import load_wine
import matplotlib.pyplot as plt 

data = load_wine()
X = data.data
Y = data.target
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.2)

dt = DecisionTreeClassifier(max_depth=2)
dt.fit(xtrain,ytrain)
y_pred = dt.predict(xtest)

print(accuracy_score(y_pred,ytest))

plot_tree(dt)

plt.show()
# Out:
# 0.8611111111111112

# %%
import mysql.connector
try:
    db = mysql.connector.connect(host='localhost',database='srinadh',charset='utf8',username='root',password='')
    print('Database Connected')
    cursor = db.cursor()
    while True:
        query = input("Query >")
        if query.lower() == "break":
            break
        cursor.execute(query)
        for x in cursor:
            print(x)
        db.commit()
except mysql.connector.Error as e:
    print("Error",e)
# Out:
# Database Connected
# Query > select * from student
# (1, 'srinadh')
# (2, 'sai')
# Query > insert into student values(3,'alpha')
# Query > select * from student
# (1, 'srinadh')
# (2, 'sai')
# (3, 'alpha')
# Query > show databases
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('srinadh',)
# ('test',)
# Query > change database mysql
# Error 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'database mysql' at line 1
